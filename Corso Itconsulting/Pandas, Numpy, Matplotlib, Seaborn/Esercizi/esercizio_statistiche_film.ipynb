# %%
import pandas as pd

# Percorso del file CSV
file_path = 'imdb_top_1000.csv'

# Caricamento dei dati nel DataFrame
df = pd.read_csv(file_path)

#le prime righe del DataFrame per confermare
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.tail()
# Out:
#                                            Poster_Link  \
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
df.describe()
# Out:
#        IMDB_Rating  Meta_score   No_of_Votes
# count  1000.000000  843.000000  1.000000e+03
# mean      7.949300   77.971530  2.736929e+05
# std       0.275491   12.376099  3.273727e+05
# min       7.600000   28.000000  2.508800e+04
# 25%       7.700000   70.000000  5.552625e+04
# 50%       7.900000   79.000000  1.385485e+05
# 75%       8.100000   87.000000  3.741612e+05
# max       9.300000  100.000000  2.343110e+06

# %%
df_n = df["Gross"].str.replace("," , "")
df_n
# Out:
# 0       28341469
# 1      134966411
# 2      534858444
# 3       57300000
# 4        4360000
#          ...
# 995          NaN
# 996          NaN
# 997     30500000
# 998          NaN
# 999          NaN
# Name: Gross, Length: 1000, dtype: object

# %%
df_n = df_n.astype(float)
df_n
# Out:
# 0       28341469.0
# 1      134966411.0
# 2      534858444.0
# 3       57300000.0
# 4        4360000.0
#           ...
# 995            NaN
# 996            NaN
# 997     30500000.0
# 998            NaN
# 999            NaN
# Name: Gross, Length: 1000, dtype: float64

# %%
df["Gross"] = df_n
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df["Runtime"] = df["Runtime"].str.replace(" min", "")
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate Runtime  \
# 0  The Shawshank Redemption          1994           A     142
# 1             The Godfather          1972           A     175
# 2           The Dark Knight          2008          UA     152
# 3    The Godfather: Part II          1974           A     202
# 4              12 Angry Men          1957           U      96
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df["Runtime"] = df["Runtime"].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   int64
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    float64
# dtypes: float64(3), int64(2), object(11)
# memory usage: 125.1+ KB

# %%
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A      142
# 1               The Godfather          1972           A      175
# 2             The Dark Knight          2008          UA      152
# ...

# %%
df_PG = df[df["Released_Year"]== "PG"]
df_PG
# Out:
#                                            Poster_Link Series_Title  \
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
#
#     Released_Year Certificate  Runtime                      Genre  \
# 966            PG           U      140  Adventure, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 966          7.6  NASA must devise a strategy to return Apollo 1...
#
#      Meta_score    Director      Star1        Star2        Star3        Star4  \
# 966        77.0  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      No_of_Votes        Gross
# 966       269197  173837933.0

# %%
df.loc[966,"Released_Year"] = "1970" 
df.iloc[966]
# Out:
# Poster_Link      https://m.media-amazon.com/images/M/MV5BNjEzYj...
# Series_Title                                             Apollo 13
# Released_Year                                                 1970
# Certificate                                                      U
# Runtime                                                        140
# Genre                                    Adventure, Drama, History
# IMDB_Rating                                                    7.6
# Overview         NASA must devise a strategy to return Apollo 1...
# Meta_score                                                    77.0
# Director                                                Ron Howard
# Star1                                                    Tom Hanks
# Star2                                                  Bill Paxton
# Star3                                                  Kevin Bacon
# Star4                                                  Gary Sinise
# ...

# %%
df["Released_Year"] = df["Released_Year"].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   int64
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   int64
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    float64
# dtypes: float64(3), int64(3), object(10)
# memory usage: 125.1+ KB

# %%
df.isnull().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df["Certificate"].unique()
# Out:
# array(['A', 'UA', 'U', 'PG-13', 'R', nan, 'PG', 'G', 'Passed', 'TV-14',
#        '16', 'TV-MA', 'Unrated', 'GP', 'Approved', 'TV-PG', 'U/A'],
#       dtype=object)

# %%
df["Genre"].unique()
# Out:
# array(['Drama', 'Crime, Drama', 'Action, Crime, Drama',
#        'Action, Adventure, Drama', 'Biography, Drama, History',
#        'Action, Adventure, Sci-Fi', 'Drama, Romance', 'Western',
#        'Action, Sci-Fi', 'Biography, Crime, Drama',
#        'Action, Adventure, Fantasy', 'Comedy, Drama, Thriller',
#        'Adventure, Drama, Sci-Fi', 'Animation, Adventure, Family',
#        'Drama, War', 'Crime, Drama, Fantasy', 'Comedy, Drama, Romance',
#        'Crime, Drama, Mystery', 'Crime, Drama, Thriller',
#        'Action, Drama, Mystery', 'Drama, Family, Fantasy', 'Drama, Music',
#        'Biography, Comedy, Drama', 'Drama, Mystery, Sci-Fi',
#        'Biography, Drama, Music', 'Crime, Mystery, Thriller',
#        'Animation, Adventure, Drama', 'Animation, Drama, War',
#        'Adventure, Comedy, Sci-Fi', 'Horror, Mystery, Thriller',
#        'Drama, Romance, War', 'Comedy, Drama, Family',
#        'Animation, Drama, Fantasy', 'Action, Biography, Drama',
# ...

# %%
df.describe()
# Out:
#        Released_Year      Runtime  IMDB_Rating  Meta_score   No_of_Votes  \
# count    1000.000000  1000.000000  1000.000000  843.000000  1.000000e+03
# mean     1991.196000   122.891000     7.949300   77.971530  2.736929e+05
# std        23.295026    28.093671     0.275491   12.376099  3.273727e+05
# min      1920.000000    45.000000     7.600000   28.000000  2.508800e+04
# 25%      1976.000000   103.000000     7.700000   70.000000  5.552625e+04
# 50%      1999.000000   119.000000     7.900000   79.000000  1.385485e+05
# 75%      2009.000000   137.000000     8.100000   87.000000  3.741612e+05
# max      2020.000000   321.000000     9.300000  100.000000  2.343110e+06
#
#               Gross
# count  8.310000e+02
# mean   6.803475e+07
# std    1.097500e+08
# min    1.305000e+03
# 25%    3.253559e+06
# 50%    2.353089e+07
# 75%    8.075089e+07
# max    9.366622e+08

# %%
df["Genre_n"] = df["Genre"].str.split(",").str[0]
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title  Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption           1994           A      142
# 1             The Godfather           1972           A      175
# 2           The Dark Knight           2008          UA      152
# 3    The Godfather: Part II           1974           A      202
# 4              12 Angry Men           1957           U       96
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt


correlation_matrix = df.select_dtypes(include=["number"]).corr()
correlation_matrix
plt.figure(figsize=(10,6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.show()

# %%
df['Released_Year_Group'] = pd.cut(df['Released_Year'], bins=range(1920, 2021, 20), right=False)
mean_Meta_score_by_Released_Year_Group = df.groupby('Released_Year_Group')['Meta_score'].mean()
mean_Meta_score_by_Released_Year_Group
# Out:
# /var/folders/rj/9yy7s4b93z54jkjksr4rjqnr0000gn/T/ipykernel_1579/2144114053.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_Meta_score_by_Released_Year_Group = df.groupby('Released_Year_Group')['Meta_score'].mean()
# Released_Year_Group
# [1920, 1940)    91.347826
# [1940, 1960)    91.066667
# [1960, 1980)    82.015873
# [1980, 2000)    75.254630
# [2000, 2020)    75.471014
# Name: Meta_score, dtype: float64

# %%
media_Genre_n = df.groupby('Genre_n')["Gross"].mean()
media_Genre_n
# Out:
# Genre_n
# Action       1.419631e+08
# Adventure    8.645499e+07
# Animation    1.279675e+08
# Biography    6.012873e+07
# Comedy       3.253759e+07
# Crime        3.419123e+07
# Drama        3.867728e+07
# Family       2.195553e+08
# Fantasy               NaN
# Film-Noir    1.278626e+06
# Horror       7.358577e+07
# Mystery      3.043953e+07
# Thriller     1.755074e+07
# Western      1.455538e+07
# Name: Gross, dtype: float64

# %%
df["Gross"] = df["Gross"].fillna(df["Gross"].mean())
df["Gross"].isnull().sum()
# Out:
# 0

# %%
df["Meta_score"] = df["Meta_score"].fillna(df["Meta_score"].mean())
df["Meta_score"].isnull().sum()
# Out:
# 0

# %%
df["Series_Title"].nunique()
# Out:
# 999

# %%
df["Director"].nunique()
# Out:
# 548

# %%
df["Genre_n"].value_counts()
# Out:
# Genre_n
# Drama        289
# Action       172
# Comedy       155
# Crime        107
# Biography     88
# Animation     82
# Adventure     72
# Mystery       12
# Horror        11
# Western        4
# Film-Noir      3
# Fantasy        2
# Family         2
# Thriller       1
# Name: count, dtype: int64

# %%
df["Certificate"].value_counts()
# Out:
# Certificate
# U           234
# A           197
# UA          175
# R           146
# PG-13        43
# PG           37
# Passed       34
# G            12
# Approved     11
# TV-PG         3
# GP            2
# TV-14         1
# 16            1
# TV-MA         1
# Unrated       1
# U/A           1
# Name: count, dtype: int64

# %%
df["Runtime"].mean()
# Out:
# 122.891

# %%
df["IMDB_Rating"].mean()
# Out:
# 7.949299999999999

# %%
df[df["IMDB_Rating"]>8.5].Series_Title.count()
# Out:
# 33

# %%
df["Series_Title"][df["IMDB_Rating"] == df["IMDB_Rating"].min()]
# Out:
# 877                         Dark Waters
# 878                           Searching
# 879    Once Upon a Time... in Hollywood
# 880                            Nelyubov
# 881                 The Florida Project
#                      ...
# 995              Breakfast at Tiffany's
# 996                               Giant
# 997               From Here to Eternity
# 998                            Lifeboat
# 999                        The 39 Steps
# Name: Series_Title, Length: 123, dtype: object

# %%
print(df.iloc[877:882])
# Out:
#                                            Poster_Link  \
# 877  https://m.media-amazon.com/images/M/MV5BODQ0M2...
# 878  https://m.media-amazon.com/images/M/MV5BMjIwOT...
# 879  https://m.media-amazon.com/images/M/MV5BOTg4ZT...
# 880  https://m.media-amazon.com/images/M/MV5BNzk2Nm...
# 881  https://m.media-amazon.com/images/M/MV5BMjg4Zm...
#
#                          Series_Title  Released_Year Certificate  Runtime  \
# 877                       Dark Waters           2019       PG-13      126
# 878                         Searching           2018         U/A      102
# 879  Once Upon a Time... in Hollywood           2019           A      161
# 880                          Nelyubov           2017           R      127
# 881               The Florida Project           2017           A      111
#
#                          Genre  IMDB_Rating  \
# 877  Biography, Drama, History          7.6
# 878   Drama, Mystery, Thriller          7.6
# 879              Comedy, Drama          7.6
# ...

# %%
df["Series_Title"][df["IMDB_Rating"] == df["IMDB_Rating"].max()]
# Out:
# 0    The Shawshank Redemption
# Name: Series_Title, dtype: object

# %%
print(df.iloc[0])
# Out:
# Poster_Link            https://m.media-amazon.com/images/M/MV5BMDFkYT...
# Series_Title                                    The Shawshank Redemption
# Released_Year                                                       1994
# Certificate                                                            A
# Runtime                                                              142
# Genre                                                              Drama
# IMDB_Rating                                                          9.3
# Overview               Two imprisoned men bond over a number of years...
# Meta_score                                                          80.0
# Director                                                  Frank Darabont
# Star1                                                        Tim Robbins
# Star2                                                     Morgan Freeman
# Star3                                                         Bob Gunton
# ...

# %%
sorted_IMDB = df.sort_values("IMDB_Rating", ascending = False)
sorted_IMDB
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 912  https://m.media-amazon.com/images/M/MV5BMTU5MD...
# 911  https://m.media-amazon.com/images/M/MV5BYmFmNj...
# 910  https://m.media-amazon.com/images/M/MV5BMjAxOT...
# 909  https://m.media-amazon.com/images/M/MV5BMjI2OD...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption           1994           A      142
# 1               The Godfather           1972           A      175
# 2             The Dark Knight           2008          UA      152
# ...

# %%
sorted_10film_IMDB = sorted_IMDB[0:10]
sorted_10film_IMDB
# Out:
#                                           Poster_Link  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5   https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6   https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7   https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 11  https://m.media-amazon.com/images/M/MV5BNWIwOD...
#
#                                          Series_Title  Released_Year  \
# 0                            The Shawshank Redemption           1994
# 1                                       The Godfather           1972
# 2                                     The Dark Knight           2008
# 3                              The Godfather: Part II           1974
# ...

# %%
ordinePrimi10voto = df.sort_values('No_of_Votes', ascending = False)[0:10]
ordinePrimi10voto
# Out:
#                                           Poster_Link  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 8   https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9   https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 6   https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 11  https://m.media-amazon.com/images/M/MV5BNWIwOD...
# 14  https://m.media-amazon.com/images/M/MV5BNzQzOT...
# 10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 5   https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
#
#                                          Series_Title  Released_Year  \
# 0                            The Shawshank Redemption           1994
# 2                                     The Dark Knight           2008
# 8                                           Inception           2010
# 9                                          Fight Club           1999
# ...

# %%
ordinePrimi10incasso = df.sort_values('Gross', ascending = False)[0:10]
ordinePrimi10incasso
# Out:
#                                            Poster_Link  \
# 477  https://m.media-amazon.com/images/M/MV5BOTAzOD...
# 59   https://m.media-amazon.com/images/M/MV5BMTc5MD...
# 623  https://m.media-amazon.com/images/M/MV5BMTYwOT...
# 60   https://m.media-amazon.com/images/M/MV5BMjMxNj...
# 652  https://m.media-amazon.com/images/M/MV5BMDdmZG...
# 357  https://m.media-amazon.com/images/M/MV5BNDYxNj...
# 891  https://m.media-amazon.com/images/M/MV5BMTEzNz...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 582  https://m.media-amazon.com/images/M/MV5BMjEwMz...
# 63   https://m.media-amazon.com/images/M/MV5BMTk4OD...
#
#                                    Series_Title  Released_Year Certificate  \
# 477  Star Wars: Episode VII - The Force Awakens           2015           U
# 59                            Avengers: Endgame           2019          UA
# 623                                      Avatar           2009          UA
# ...

# %%
A = sorted_10film_IMDB["Series_Title"].values
A
# Out:
# array(['12 Angry Men', 'Forrest Gump', 'Pulp Fiction', "Schindler's List",
#        'The Dark Knight', 'The Godfather', 'The Godfather: Part II',
#        'The Lord of the Rings: The Fellowship of the Ring',
#        'The Lord of the Rings: The Return of the King',
#        'The Shawshank Redemption'], dtype=object)

# %%
B = ordinePrimi10incasso["Series_Title"].values
B
# Out:
# array(['Star Wars: Episode VII - The Force Awakens', 'Avengers: Endgame',
#        'Avatar', 'Avengers: Infinity War', 'Titanic', 'The Avengers',
#        'Incredibles 2', 'The Dark Knight', 'Rogue One',
#        'The Dark Knight Rises'], dtype=object)

# %%
import numpy as np
common_values_A_B = np.intersect1d(A, B)
common_values_A_B
# Out:
# array(['The Dark Knight'], dtype=object)

# %%
C = ordinePrimi10voto["Series_Title"].values
C
# Out:
# array(['The Shawshank Redemption', 'The Dark Knight', 'Inception',
#        'Fight Club', 'Pulp Fiction', 'Forrest Gump', 'The Matrix',
#        'The Lord of the Rings: The Fellowship of the Ring',
#        'The Lord of the Rings: The Return of the King', 'The Godfather'],
#       dtype=object)

# %%
common_values_A_C=np.intersect1d(A, C)
common_values_A_C
# Out:
# array(['Forrest Gump', 'Pulp Fiction', 'The Dark Knight', 'The Godfather',
#        'The Lord of the Rings: The Fellowship of the Ring',
#        'The Lord of the Rings: The Return of the King',
#        'The Shawshank Redemption'], dtype=object)

# %%
df['No_of_Votes_Group'] = pd.cut(df['No_of_Votes'], bins=range(df["No_of_Votes"].min(),df["No_of_Votes"].max(), 10000), right=False)
mean_rating_byvotesgroup = df.groupby('No_of_Votes_Group')['IMDB_Rating'].mean()
mean_rating_byvotesgroup

# %%
df["Genre_n"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df["Genre_n"].value_counts()
#
# NameError: name 'df' is not defined
